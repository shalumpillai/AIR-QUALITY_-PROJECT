# %%
# import the necessary libraries
import numpy as np
import pandas as pd

# Visualisation libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading and Understanding the dataset

# %%
# Loading the data as df
df=pd.read_csv('city_day.csv')
#Converting String to Datetime
df['Date'] = pd.to_datetime(df['Date'])
print(np.dtype(df['Date']))
df.rename(columns = {'AQI_Bucket':'Air_quality'}, inplace = True)
df.head()
# Out:
# datetime64[ns]
#         City       Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad 2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad 2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad 2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad 2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad 2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI Air_quality
# 0  133.36     0.00     0.02    0.00  NaN         NaN
# 1   34.06     3.68     5.50    3.77  NaN         NaN
# 2   30.70     6.80    16.40    2.25  NaN         NaN
# 3   36.08     4.43    10.14    1.00  NaN         NaN
# 4   39.31     7.01    18.89    2.78  NaN         NaN

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'Air_quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         29531 non-null  object
#  1   Date         29531 non-null  datetime64[ns]
#  2   PM2.5        24933 non-null  float64
#  3   PM10         18391 non-null  float64
#  4   NO           25949 non-null  float64
#  5   NO2          25946 non-null  float64
#  6   NOx          25346 non-null  float64
#  7   NH3          19203 non-null  float64
#  8   CO           27472 non-null  float64
#  9   SO2          25677 non-null  float64
#  10  O3           25509 non-null  float64
#  11  Benzene      23908 non-null  float64
#  12  Toluene      21490 non-null  float64
#  13  Xylene       11422 non-null  float64
#  14  AQI          24850 non-null  float64
#  15  Air_quality  24850 non-null  object
# dtypes: datetime64[ns](1), float64(13), object(2)
# memory usage: 3.6+ MB

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# std       25.684275      6.962884     18.133775     21.694928     15.811136
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.580000      0.510000      5.670000     18.860000      0.120000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       30.020000      1.450000     15.220000     45.570000      3.080000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  21490.000000  11422.000000  24850.000000
# mean       8.700972      3.070128    166.463581
# std       19.969164      6.323247    140.696585
# min        0.000000      0.000000     13.000000
# 25%        0.600000      0.140000     81.000000
# 50%        2.970000      0.980000    118.000000
# 75%        9.150000      3.350000    208.000000
# max      454.850000    170.370000   2049.000000

# %%
# Data availability
print(f"The available data we have is between {df['Date'].min()} and {df['Date'].max()}")
# Out:
# The available data we have is between 2015-01-01 00:00:00 and 2020-07-01 00:00:00

# %%
# How many rows available for each City.
df['City'].value_counts()
# Out:
# Ahmedabad             2009
# Delhi                 2009
# Mumbai                2009
# Bengaluru             2009
# Lucknow               2009
# Chennai               2009
# Hyderabad             2006
# Patna                 1858
# Gurugram              1679
# Visakhapatnam         1462
# Amritsar              1221
# Jorapokhar            1169
# Jaipur                1114
# Thiruvananthapuram    1112
# Amaravati              951
# Brajrajnagar           938
# Talcher                925
# Kolkata                814
# Guwahati               502
# Coimbatore             386
# Shillong               310
# Chandigarh             304
# Bhopal                 289
# Ernakulam              162
# Kochi                  162
# Aizawl                 113
# Name: City, dtype: int64

# %%
df[df['Air_quality']=='Severe']['City'].value_counts() 
#Here Ahmedabad,Delhi,Patna seems to be highest in case and Ahemdabad to be very much higher than others.
# Out:
# Ahmedabad     638
# Delhi         239
# Patna         174
# Lucknow       110
# Gurugram       95
# Talcher        24
# Jorapokhar     18
# Kolkata        13
# Amritsar        7
# Hyderabad       7
# Chennai         6
# Guwahati        5
# Jaipur          2
# Name: City, dtype: int64

# %%
pd.to_datetime(df[(df['Air_quality']=='Severe')&(df['City']=='Ahmedabad')]['Date']).dt.year.value_counts()
# Out:
# 2018    277
# 2019    224
# 2015     51
# 2017     37
# 2020     29
# 2016     20
# Name: Date, dtype: int64

# %% [markdown]
# * **As we see here,in the city of Ahmedabad year 2018,2019 severe instances has been found and the condition of air quality was harmful.**

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Missing value Treatment

# %%
def missing_value_table(df):
    values = df.isnull().sum()
    percentage = 100*df.isnull().sum()/len(df)
    table = pd.concat([values,percentage.round(2)],axis=1)
    table.columns = ['No of missing values','% of missing values']
    return table[table['No of missing values']!=0].sort_values('% of missing values',ascending=False).style.background_gradient('Reds')
missing_value_table(df)
# Out:
# <style type="text/css">
# #T_c2d15_row0_col0, #T_c2d15_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c2d15_row1_col0, #T_c2d15_row1_col1 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# #T_c2d15_row2_col0, #T_c2d15_row2_col1 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_c2d15_row3_col0, #T_c2d15_row3_col1 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_c2d15_row4_col0, #T_c2d15_row4_col1 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_c2d15_row5_col0, #T_c2d15_row5_col1, #T_c2d15_row6_col0, #T_c2d15_row6_col1 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_c2d15_row7_col0, #T_c2d15_row7_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_c2d15_row8_col0, #T_c2d15_row8_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_c2d15_row9_col0, #T_c2d15_row9_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_c2d15_row10_col0, #T_c2d15_row10_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_c2d15_row11_col0, #T_c2d15_row11_col1, #T_c2d15_row12_col0, #T_c2d15_row12_col1 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_c2d15_row13_col0, #T_c2d15_row13_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_c2d15_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >No of missing values</th>
#       <th class="col_heading level0 col1" >% of missing values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2d15_level0_row0" class="row_heading level0 row0" >Xylene</th>
#       <td id="T_c2d15_row0_col0" class="data row0 col0" >18109</td>
#       <td id="T_c2d15_row0_col1" class="data row0 col1" >61.320000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row1" class="row_heading level0 row1" >PM10</th>
#       <td id="T_c2d15_row1_col0" class="data row1 col0" >11140</td>
#       <td id="T_c2d15_row1_col1" class="data row1 col1" >37.720000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row2" class="row_heading level0 row2" >NH3</th>
#       <td id="T_c2d15_row2_col0" class="data row2 col0" >10328</td>
#       <td id="T_c2d15_row2_col1" class="data row2 col1" >34.970000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row3" class="row_heading level0 row3" >Toluene</th>
#       <td id="T_c2d15_row3_col0" class="data row3 col0" >8041</td>
#       <td id="T_c2d15_row3_col1" class="data row3 col1" >27.230000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row4" class="row_heading level0 row4" >Benzene</th>
#       <td id="T_c2d15_row4_col0" class="data row4 col0" >5623</td>
#       <td id="T_c2d15_row4_col1" class="data row4 col1" >19.040000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row5" class="row_heading level0 row5" >AQI</th>
#       <td id="T_c2d15_row5_col0" class="data row5 col0" >4681</td>
#       <td id="T_c2d15_row5_col1" class="data row5 col1" >15.850000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row6" class="row_heading level0 row6" >Air_quality</th>
#       <td id="T_c2d15_row6_col0" class="data row6 col0" >4681</td>
#       <td id="T_c2d15_row6_col1" class="data row6 col1" >15.850000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row7" class="row_heading level0 row7" >PM2.5</th>
#       <td id="T_c2d15_row7_col0" class="data row7 col0" >4598</td>
#       <td id="T_c2d15_row7_col1" class="data row7 col1" >15.570000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row8" class="row_heading level0 row8" >NOx</th>
#       <td id="T_c2d15_row8_col0" class="data row8 col0" >4185</td>
#       <td id="T_c2d15_row8_col1" class="data row8 col1" >14.170000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row9" class="row_heading level0 row9" >O3</th>
#       <td id="T_c2d15_row9_col0" class="data row9 col0" >4022</td>
#       <td id="T_c2d15_row9_col1" class="data row9 col1" >13.620000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row10" class="row_heading level0 row10" >SO2</th>
#       <td id="T_c2d15_row10_col0" class="data row10 col0" >3854</td>
#       <td id="T_c2d15_row10_col1" class="data row10 col1" >13.050000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row11" class="row_heading level0 row11" >NO2</th>
#       <td id="T_c2d15_row11_col0" class="data row11 col0" >3585</td>
#       <td id="T_c2d15_row11_col1" class="data row11 col1" >12.140000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row12" class="row_heading level0 row12" >NO</th>
#       <td id="T_c2d15_row12_col0" class="data row12 col0" >3582</td>
#       <td id="T_c2d15_row12_col1" class="data row12 col1" >12.130000</td>
#     </tr>
#     <tr>
#       <th id="T_c2d15_level0_row13" class="row_heading level0 row13" >CO</th>
#       <td id="T_c2d15_row13_col0" class="data row13 col0" >2059</td>
#       <td id="T_c2d15_row13_col1" class="data row13 col1" >6.970000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#import the missingno plot and checking missing values.
import missingno 
missingno.bar(df, color="green")
# Out:
# <AxesSubplot:>

# %% [markdown]
# * In this bar chart of missing values, we can see that **Xylene, PM10** and **NH3** is mostly have the missing values.
# * **we can also see that we don't have any missing values in the City and Date column.**
# * **We can see that there is a relation between AQI and AQI_Bucket. when the AQI is missing, AQI_Bucket is also missing.**

# %%
# Treating missing values in the copy of df
df1=df.copy()
df1_columns=['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
       'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI']
for i in df1_columns:
    df1[i]=df1[i].fillna(df1[i].median())
df1['Air_quality']=df1['Air_quality'].fillna('Moderate')

# %%
df1.isna().sum()
# Out:
# City           0
# Date           0
# PM2.5          0
# PM10           0
# NO             0
# NO2            0
# NOx            0
# NH3            0
# CO             0
# SO2            0
# O3             0
# Benzene        0
# Toluene        0
# Xylene         0
# AQI            0
# Air_quality    0
# dtype: int64

# %% [markdown]
# ## UNIVERIATE ANALYSIS

# %% [markdown]
# ## Distribusion of AQI

# %%
# Plotting distribusion of Air quality
print(df1['Air_quality'].value_counts(ascending= True))
sns.catplot(x = 'Air_quality', kind= "count", palette = "ch: 2.87", height=5, aspect=1.1, data = df1)
# Out:
# Severe           1338
# Good             1341
# Very Poor        2337
# Poor             2781
# Satisfactory     8224
# Moderate        13510
# Name: Air_quality, dtype: int64

# %% [markdown]
# **Mainly there are six categories of AQI which we observe: Good, Satisfactory, Moderate, Poor, Very Poor and Severe.**

# %% [markdown]
# ## Range of AQI

# %%
df2=df1.copy()
df2['year'] = df2['Date'].dt.year
print(f"Minimum and maximum range of AQI: {df2.AQI.min()} - {df2.AQI.max()}")
plt.title('AQI levels over 2015 to 2020')
sns.lineplot(x='year',y='AQI', data=df2);
# Out:
# Minimum and maximum range of AQI: 13.0 - 2049.0

# %% [markdown]
# * **We observe a general decline in the AQI levels over the years which shows increase in Air Quality.**

# %% [markdown]
# ## Histogram of features

# %%
a=df1.drop('Date',axis=1)
plt.rcParams['figure.figsize']=(15,15)
a.hist(bins=20,color='pink')
plt.show()

# %% [markdown]
# #### Each of the histograms are right Skewed or Positively Skewed. That means, Mean, Median, Modes are all different.

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %% [markdown]
# ## Correlation Analysis

# %%
#Analyze the Correlation between Columns.
#correlation analysis

plt.figure(figsize=(12,8))

mask=np.triu(df.corr(method='pearson'))
sns.heatmap(df.corr(method='pearson'),
            annot=True,fmt='0.1f',
            mask=mask,
            robust=True,
            cmap='pink')
plt.title('Correlation Analysis', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Correlation Analysis')

# %% [markdown]
# * **From the above heatmap, we observe a strong correlation of NO WITH NOX, NO2 WITH NOX AND BENZENE WITH TOLUENE.**

# %%
#Let's first visualize their correlation.
# Checking relationship between NO and NOx
plt.figure(figsize=(12,8))
sns.scatterplot(x='NO',y='NOx',data=df,s=70,color='green')
plt.title('Correlation of NO with NOx', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Correlation of NO with NOx')

# %%
# Checking relationship between NO2 and NOx.
plt.figure(figsize=(12,8))
sns.scatterplot(x='NO2',y='NOx',data=df,s=70,color='Blue')
plt.title("Correlation of NO2 with NOx", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Correlation of NO2 with NOx')

# %% [markdown]
# * **In the First two scatter plots, we observe that there is a correlation between NO, NO2 and NOx and it's obvious because all these three elements are the member of seven gases and compounds group composed of Nitrogen and Oxygen.**

# %%
# Checking relationship between Benzene and Toluene.
plt.figure(figsize=(12,8))
sns.scatterplot(x='Benzene',y='Toluene',data=df,s=80,color='Red')
plt.title("Correlation of Benzene with Toluene", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Correlation of Benzene with Toluene')

# %% [markdown]
# * **In this plot we observe a correlation between Benzene and Toluene and this time, its again obvious because Benzene, Toluene and Xylene are well known indoor air pollutants. sometimes its called as BTX.**

# %%
# Checking the relation between each pollution content and AQI
df2=df1.copy()
variables = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']
df2['year'] = df2['Date'].dt.year
fig = plt.figure(figsize=(16,34))
for variable,num in zip(variables, range(1,len(variables)+1)):
    ax = fig.add_subplot(6,2,num)
    sns.scatterplot(variable,'AQI', hue='year', data=df2,palette='viridis')
    plt.title('Relation between {} and AQI'.format(variable))
    plt.xlabel(variable)
    plt.ylabel('AQI')

# %% [markdown]
# * **PM2.5 -> This shows a inversely proportional behaviour since when it's value remains low the AQI value increases while in other cases when its value increases the AQI value reamins low.**
# * **PM10 -> This also shows an inverse behaviour except for the fact that even when PM10 value is less AQI value doesn't increase much.**

# %% [markdown]
# ## The pollution levels with repect to time

# %%
#The pollution levels with repect to time
df2=df1.copy()
df2.set_index('Date',inplace=True) 
df2['BTX'] = df2['Xylene'] + df2['Toluene'] + df2['Benzene']
pollutants=['PM2.5','PM10','SO2','BTX','CO','NH3','NO2']

axes=df2[pollutants].plot(marker='.',figsize=(16,20),subplots=True,alpha=0.3)
for axes in axes:
    axes.set_xlabel('Years',fontsize=16)
    axes.set_ylabel('Concentration',fontsize=12)
plt.show()

# %% [markdown]
# * **There are indications of seasonality towards the increase in PM2.5 and PM10 levels.**
# * **We should take a closer look to determine the exact nature of the trend.**
# * **We can also observe a clear increase in SO2, CO and BTX levels from 2018 onwards.**

# %%
df2=df1.copy()
df2['year'] = df2['Date'].dt.year
df2['year'] = df2['year'].astype(str)
temp = df2.groupby(['year'])[['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 
                                                  'NH3', 'CO', 'SO2','O3', 'Benzene', 
                                                  'Toluene', 'Xylene', 'AQI']].median()
temp.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_bde53_row0_col0, #T_bde53_row0_col1, #T_bde53_row0_col5, #T_bde53_row0_col6, #T_bde53_row0_col10, #T_bde53_row0_col12, #T_bde53_row1_col0, #T_bde53_row1_col1, #T_bde53_row1_col5, #T_bde53_row1_col10, #T_bde53_row1_col12, #T_bde53_row2_col0, #T_bde53_row2_col1, #T_bde53_row2_col5, #T_bde53_row2_col12, #T_bde53_row3_col0, #T_bde53_row3_col1, #T_bde53_row3_col2, #T_bde53_row3_col3, #T_bde53_row3_col4, #T_bde53_row3_col5, #T_bde53_row3_col10, #T_bde53_row3_col12, #T_bde53_row4_col1, #T_bde53_row4_col5, #T_bde53_row4_col7, #T_bde53_row4_col10, #T_bde53_row5_col8, #T_bde53_row5_col10 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_bde53_row0_col2, #T_bde53_row1_col2, #T_bde53_row2_col2 {
#   background-color: #b81419;
#   color: #f1f1f1;
# }
# #T_bde53_row0_col3 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_bde53_row0_col4, #T_bde53_row0_col7, #T_bde53_row2_col7, #T_bde53_row5_col7 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_bde53_row0_col8, #T_bde53_row1_col8, #T_bde53_row2_col8, #T_bde53_row3_col8 {
#   background-color: #fc8060;
#   color: #f1f1f1;
# }
# #T_bde53_row0_col9, #T_bde53_row0_col11, #T_bde53_row1_col7, #T_bde53_row1_col9, #T_bde53_row1_col11, #T_bde53_row2_col6, #T_bde53_row2_col9, #T_bde53_row2_col10, #T_bde53_row2_col11, #T_bde53_row3_col9, #T_bde53_row3_col11, #T_bde53_row4_col8, #T_bde53_row4_col9, #T_bde53_row4_col11, #T_bde53_row5_col0, #T_bde53_row5_col1, #T_bde53_row5_col2, #T_bde53_row5_col3, #T_bde53_row5_col4, #T_bde53_row5_col5, #T_bde53_row5_col9, #T_bde53_row5_col11, #T_bde53_row5_col12 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_bde53_row1_col3, #T_bde53_row2_col3 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_bde53_row1_col4, #T_bde53_row2_col4 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_bde53_row1_col6 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_bde53_row3_col6 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_bde53_row3_col7 {
#   background-color: #fc8969;
#   color: #f1f1f1;
# }
# #T_bde53_row4_col0 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_bde53_row4_col2 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_bde53_row4_col3 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_bde53_row4_col4 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_bde53_row4_col6 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_bde53_row4_col12 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_bde53_row5_col6 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# </style>
# <table id="T_bde53_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >PM2.5</th>
#       <th class="col_heading level0 col1" >PM10</th>
#       <th class="col_heading level0 col2" >NO</th>
#       <th class="col_heading level0 col3" >NO2</th>
#       <th class="col_heading level0 col4" >NOx</th>
#       <th class="col_heading level0 col5" >NH3</th>
#       <th class="col_heading level0 col6" >CO</th>
#       <th class="col_heading level0 col7" >SO2</th>
#       <th class="col_heading level0 col8" >O3</th>
#       <th class="col_heading level0 col9" >Benzene</th>
#       <th class="col_heading level0 col10" >Toluene</th>
#       <th class="col_heading level0 col11" >Xylene</th>
#       <th class="col_heading level0 col12" >AQI</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bde53_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_bde53_row0_col0" class="data row0 col0" >48.570000</td>
#       <td id="T_bde53_row0_col1" class="data row0 col1" >95.680000</td>
#       <td id="T_bde53_row0_col2" class="data row0 col2" >9.890000</td>
#       <td id="T_bde53_row0_col3" class="data row0 col3" >21.290000</td>
#       <td id="T_bde53_row0_col4" class="data row0 col4" >22.270000</td>
#       <td id="T_bde53_row0_col5" class="data row0 col5" >15.850000</td>
#       <td id="T_bde53_row0_col6" class="data row0 col6" >1.580000</td>
#       <td id="T_bde53_row0_col7" class="data row0 col7" >9.160000</td>
#       <td id="T_bde53_row0_col8" class="data row0 col8" >30.840000</td>
#       <td id="T_bde53_row0_col9" class="data row0 col9" >1.070000</td>
#       <td id="T_bde53_row0_col10" class="data row0 col10" >2.970000</td>
#       <td id="T_bde53_row0_col11" class="data row0 col11" >0.980000</td>
#       <td id="T_bde53_row0_col12" class="data row0 col12" >118.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bde53_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_bde53_row1_col0" class="data row1 col0" >48.570000</td>
#       <td id="T_bde53_row1_col1" class="data row1 col1" >95.680000</td>
#       <td id="T_bde53_row1_col2" class="data row1 col2" >9.890000</td>
#       <td id="T_bde53_row1_col3" class="data row1 col3" >21.690000</td>
#       <td id="T_bde53_row1_col4" class="data row1 col4" >23.520000</td>
#       <td id="T_bde53_row1_col5" class="data row1 col5" >15.850000</td>
#       <td id="T_bde53_row1_col6" class="data row1 col6" >0.960000</td>
#       <td id="T_bde53_row1_col7" class="data row1 col7" >8.705000</td>
#       <td id="T_bde53_row1_col8" class="data row1 col8" >30.840000</td>
#       <td id="T_bde53_row1_col9" class="data row1 col9" >1.070000</td>
#       <td id="T_bde53_row1_col10" class="data row1 col10" >2.970000</td>
#       <td id="T_bde53_row1_col11" class="data row1 col11" >0.980000</td>
#       <td id="T_bde53_row1_col12" class="data row1 col12" >118.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bde53_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_bde53_row2_col0" class="data row2 col0" >48.570000</td>
#       <td id="T_bde53_row2_col1" class="data row2 col1" >95.680000</td>
#       <td id="T_bde53_row2_col2" class="data row2 col2" >9.890000</td>
#       <td id="T_bde53_row2_col3" class="data row2 col3" >21.690000</td>
#       <td id="T_bde53_row2_col4" class="data row2 col4" >23.520000</td>
#       <td id="T_bde53_row2_col5" class="data row2 col5" >15.850000</td>
#       <td id="T_bde53_row2_col6" class="data row2 col6" >0.650000</td>
#       <td id="T_bde53_row2_col7" class="data row2 col7" >9.160000</td>
#       <td id="T_bde53_row2_col8" class="data row2 col8" >30.840000</td>
#       <td id="T_bde53_row2_col9" class="data row2 col9" >1.070000</td>
#       <td id="T_bde53_row2_col10" class="data row2 col10" >2.750000</td>
#       <td id="T_bde53_row2_col11" class="data row2 col11" >0.980000</td>
#       <td id="T_bde53_row2_col12" class="data row2 col12" >118.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bde53_level0_row3" class="row_heading level0 row3" >2018</th>
#       <td id="T_bde53_row3_col0" class="data row3 col0" >48.570000</td>
#       <td id="T_bde53_row3_col1" class="data row3 col1" >95.680000</td>
#       <td id="T_bde53_row3_col2" class="data row3 col2" >10.210000</td>
#       <td id="T_bde53_row3_col3" class="data row3 col3" >24.540000</td>
#       <td id="T_bde53_row3_col4" class="data row3 col4" >26.540000</td>
#       <td id="T_bde53_row3_col5" class="data row3 col5" >15.850000</td>
#       <td id="T_bde53_row3_col6" class="data row3 col6" >0.900000</td>
#       <td id="T_bde53_row3_col7" class="data row3 col7" >9.210000</td>
#       <td id="T_bde53_row3_col8" class="data row3 col8" >30.840000</td>
#       <td id="T_bde53_row3_col9" class="data row3 col9" >1.070000</td>
#       <td id="T_bde53_row3_col10" class="data row3 col10" >2.970000</td>
#       <td id="T_bde53_row3_col11" class="data row3 col11" >0.980000</td>
#       <td id="T_

# %% [markdown]
# * **We can see in 2020, there has been a decrease in air pollution.And we all know it may be because of effects of covid19 and lockdown.This is the world's largest lockdown.**

# %% [markdown]
# ## Average AQI over the Years

# %%
# Average AQI over the Years for different Cities.
df2=df1.copy()
df2['City'][df2['AQI']>=500].value_counts()
cols = df2['City'].unique()
df2['Year'] = df2.Date.dt.year.astype(int)
for col in cols:
    plt.figure(figsize=(12,8))
    x= df2[df2['City']==col]
    sns.barplot(x='Year', y='AQI', data=x, palette ='Paired')
    plt.title(f"Average AQI over the Years for {col}", fontsize=16)
    display()

# %% [markdown]
# **After analyzing the Average AQI level for different cities over Years, we found that most of the cities are performing good to tackle the problem of Air Pollution. Their Average AQI level is shrinking Year by Year**

# %%
cities = ['Delhi', 'Ahmedabad', 'Hyderabad', 'Bengaluru', 'Kolkata']
fig,ax = plt.subplots(figsize=(15, 7))

for city in cities: 
    sns.lineplot(x="Date", y="AQI", data=df1[df1['City']==city].iloc[::30],label = city)

ax.set_xticklabels(ax.get_xticklabels(cities), rotation=30, ha="left")

ax.set_title('AQI values in cities')
ax.legend()

# %% [markdown]
# * **As expected we can see maximum amounts of pollutants in metropolitan cities with large populations and significant
#   commercial and maunfacturing activities.**

# %% [markdown]
# ## Impact of particular matter on city air quality

# %%
# Plotting Pie Plots for City Air
ex = 0.2,0,0,0,0,0,0,0
cols = 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene'
color = 'darkred', 'navy', 'darkorange', 'sandybrown', 'darkgreen', 'peru', 'olivedrab', 'darkslategray'
for col in cols:
    plt.figure(figsize=(12,8))
    x= df1.groupby('City')[col].sum().sort_values(ascending=False)
    x.reset_index('City')
    x[ :8].plot.pie(shadow=True, autopct='%1.1f%%', colors=color, explode=ex, wedgeprops={'edgecolor':'black', 'linewidth':0.3})
    plt.title(f"The Impact of {col} on the Top 8 Cities.", fontsize=16)

# %% [markdown]
# * **After analyzing the above Pie charts, we observe that 'Ahmedabad', 'Delhi', 'Bengaluru', 'Mumbai', 'Hyderabad' and 'Chennai' are the most polluted cities of India.**
# * **Ahmadabad city Air contains 82% of the total Carbon Monoxides(CO) of the Country. Carbon Monooxides is a highly poisenues gas.**
# * **Mumbai City Air contains 44% of the total Sulpher dioxide(SO2) of the Country.**

# %% [markdown]
# ## Cities with Good Air Quality.

# %%
# Cities with Good Air
x= pd.DataFrame(df1['City'][df1['AQI']<=50].value_counts())
x= x.rename(columns={'City':'Counts'})
plt.figure(figsize=(12,8))
sns.barplot(x='Counts', y=x.index, data=x, palette= 'magma')
plt.title("List of Cities with Good Air Quality.", fontsize=16);

# %% [markdown]
# * **we observe that Amaravati and Hyderabad are the Top 2 City with the Good Air Quality. For more than 200 times, these two cities encounter AQI less than 50 while it is hard for other cities to get it for more than 150.**

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Missing Value treatment

# %%
# let us check the percentage of missing values in each column
(df.isnull().sum()/df.shape[0]*100).sort_values(ascending=False)
# Out:
# Xylene         61.322001
# PM10           37.723071
# NH3            34.973418
# Toluene        27.229014
# Benzene        19.041008
# AQI            15.851139
# Air_quality    15.851139
# PM2.5          15.570079
# NOx            14.171549
# O3             13.619586
# SO2            13.050692
# NO2            12.139785
# NO             12.129626
# CO              6.972334
# City            0.000000
# Date            0.000000
# dtype: float64

# %% [markdown]
# * **All columns have missing values excluding Date and City colunms.**
# * **Among them Xylene shows higher percentage (61%) of missing values.**

# %%
# plotting heat map of missing values for getiing a clear visualization
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Imputing the missing values using BFILL

# %%
# missing value imputation
df.fillna(method='bfill',inplace=True)
df.isna().sum()
# Out:
# City           0
# Date           0
# PM2.5          0
# PM10           0
# NO             0
# NO2            0
# NOx            0
# NH3            0
# CO             0
# SO2            0
# O3             0
# Benzene        1
# Toluene        1
# Xylene         1
# AQI            0
# Air_quality    0
# dtype: int64

# %%
# still we are seeing 3 nan values ,so we can drop them.
df.dropna(inplace=True)

# %%
# let us plot heatmap after the imputation
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# * **Now there is no more missing values present in data.**

# %% [markdown]
# ## Encoding

# %%
df['Air_quality'].unique()
# Out:
# array(['Poor', 'Very Poor', 'Severe', 'Moderate', 'Satisfactory', 'Good'],
#       dtype=object)

# %%
df['Air_quality'] = df['Air_quality'].map({'Good' :0,'Satisfactory' :1,'Moderate' :2,'Poor' :3,'Very Poor' :4,'Severe' :5}).astype(int)#mapping

# %%
df.nunique()
# Out:
# City              26
# Date            2009
# PM2.5          11716
# PM10           12570
# NO              5776
# NO2             7404
# NOx             8156
# NH3             5922
# CO              1779
# SO2             4761
# O3              7699
# Benzene         1873
# Toluene         3608
# Xylene          1561
# AQI              829
# Air_quality        6
# dtype: int64

# %% [markdown]
# ## Outlier detection

# %%
# plotting boxplot of all columns except Date,City and Air_quality columns for checking the outliers present.
col=['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
       'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI','Air_quality']
for i in col:
    sns.boxplot(x=df[i])
    plt.show()

# %% [markdown]
# * **We can see that all the columns contain huge number of outliers.when removing all these ,will effect the nature of entire data.**

# %% [markdown]
# ## Feature Reduction and Feature Engineering

# %%
# setting Date column as index
df=df.set_index(['Date'])
# Droping column which have low importance
df=df.drop(['City'],axis=1)
df.head()
# Out:
#             PM2.5    PM10     NO    NO2    NOx    NH3     CO    SO2      O3  \
# Date
# 2015-01-01  73.24  141.54   0.92  18.22  17.15  26.64   0.92  27.64  133.36
# 2015-01-02  73.24  141.54   0.97  15.69  16.46  26.64   0.97  24.55   34.06
# 2015-01-03  73.24  141.54  17.40  19.30  29.70  26.64  17.40  29.07   30.70
# 2015-01-04  73.24  141.54   1.70  18.48  17.97  26.64   1.70  18.59   36.08
# 2015-01-05  73.24  141.54  22.10  21.42  37.76  26.64  22.10  39.33   39.31
#
#             Benzene  Toluene  Xylene    AQI  Air_quality
# Date
# 2015-01-01     0.00     0.02    0.00  209.0            3
# 2015-01-02     3.68     5.50    3.77  209.0            3
# 2015-01-03     6.80    16.40    2.25  209.0            3
# 2015-01-04     4.43    10.14    1.00  209.0            3
# 2015-01-05     7.01    18.89    2.78  209.0            3

# %% [markdown]
# **now, we can  divide the pollution components into two part namely Vehicular Pollution content (PM2.5, PM10, NO2, NH3, CO,) and Industrial Pollution content (CO, SO2, O3, Benzene, Toluene, Xylene) and adding these as new columns.**

# %%
df['Vehicular Pollution content'] = df['PM2.5']+df['PM10']+df['NO']+df['NO2']+df['NOx']+df['NH3']+df['CO']
df['Industrial Pollution content'] = df['SO2']+df['O3']+df['Benzene']+df['Toluene']+df['Xylene']
df.head()
# Out:
#             PM2.5    PM10     NO    NO2    NOx    NH3     CO    SO2      O3  \
# Date
# 2015-01-01  73.24  141.54   0.92  18.22  17.15  26.64   0.92  27.64  133.36
# 2015-01-02  73.24  141.54   0.97  15.69  16.46  26.64   0.97  24.55   34.06
# 2015-01-03  73.24  141.54  17.40  19.30  29.70  26.64  17.40  29.07   30.70
# 2015-01-04  73.24  141.54   1.70  18.48  17.97  26.64   1.70  18.59   36.08
# 2015-01-05  73.24  141.54  22.10  21.42  37.76  26.64  22.10  39.33   39.31
#
#             Benzene  Toluene  Xylene    AQI  Air_quality  \
# Date
# 2015-01-01     0.00     0.02    0.00  209.0            3
# 2015-01-02     3.68     5.50    3.77  209.0            3
# 2015-01-03     6.80    16.40    2.25  209.0            3
# 2015-01-04     4.43    10.14    1.00  209.0            3
# 2015-01-05     7.01    18.89    2.78  209.0            3
#
#             Vehicular Pollution content  Industrial Pollution content
# Date
# 2015-01-01                       278.63                        161.02
# 2015-01-02                       275.51                         71.56
# 2015-01-03                       325.22                         85.22
# 2015-01-04                       281.27                         70.24
# 2015-01-05                       344.80                        107.32

# %% [markdown]
# ## Checking Correlation

# %%
# Plotting heatmap to find the correlation between the columns
corr_matrix=df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr_matrix,vmin=-0.6,vmax=0.9,linewidth=0.3,annot=True,cmap='Greens')
plt.show()

# %% [markdown]
# ## Modelling

# %%
# Separate the data into feature data and target data (X and y, respectively)

y = df["Air_quality"]
x= df[['AQI']]

print(x.shape)
print(y.shape)
# Out:
# (29530, 1)
# (29530,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size = 0.3, random_state=0)

# %%
from collections import Counter
print('Classes and number of values in trainset',Counter(y_train))
# Out:
# Classes and number of values in trainset Counter({1: 7197, 2: 7167, 3: 2264, 4: 1816, 0: 1136, 5: 1091})

# %% [markdown]
# ### Data Imbalance:

# %% [markdown]
# Here we observe that target label is not splitted eqaully. This will cause data imbalance problem. In order to overcome
# this problem we use the technique called SMOTE(Synthetic Minority Oversampling Technique). This approach solve this problem
# by oversample the examples in the minority class.

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X_train,y_train = oversample.fit_resample(X_train,y_train)
print('Classes and number of values in trainset after SMOTE:',Counter(y_train))
# Out:
# Classes and number of values in trainset after SMOTE: Counter({1: 7197, 2: 7197, 3: 7197, 4: 7197, 5: 7197, 0: 7197})

# %% [markdown]
# ### 1. **1. Support Vector Machine**

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.svm import SVC
cls=SVC()
cls.fit(X_train,y_train)
svmpred=cls.predict(X_test)
svmpred
cm=confusion_matrix(y_test,svmpred)
print("confussion matrix")
print(cm)
print("\n")
accuracy=accuracy_score(y_test,svmpred)
print("accuracy",accuracy*100)
# Out:
# confussion matrix
# [[ 473    0    0    0    0    0]
#  [ 145 2895    0    0    0    0]
#  [   0    0 3069   59    0    0]
#  [   0    0    0  971   13    0]
#  [   0    0    0    0  805    7]
#  [   0    0    0    0    0  422]]
#
#
# accuracy 97.47149791172819

# %%
print('Enter the value of AQI :')
AQI = float(input('AQI :'))
output = cls.predict([[AQI]])
output 

# 0-->Good
# 1-->Satisfactory
# 2-->moderate
# 3-->poor
# 4-->Very poor
# 5-->Severe
# Out:
# Enter the value of AQI :

# %%
from IPython import display
display.Image('air_pollution_standards_cpcb.png',width = 400,height = 300)
